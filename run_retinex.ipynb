# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/trans_experiments/blob/main/run_retinex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !git clone https://github.com/aasharma90/RetinexNet_PyTorch.git
# %cd RetinexNet_PyTorch/
# Out:
# /content/RetinexNet_PyTorch

# %%
# !cp /content/drive/MyDrive/deweather/input.zip .
# !unzip input.zip
# !mkdir results
# !python predict.py --data_dir ./input --res_dir ./results
# !zip -r input_run_retinex.zip ./results
# !cp input_run_retinex.zip /content/drive/MyDrive/deweather/
# Out:
# Archive:  input.zip
# replace input/348.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: input/348.png
#   inflating: input/412.png
#   inflating: input/374.png
#   inflating: input/360.png
#   inflating: input/406.png
#   inflating: input/638.png
#   inflating: input/176.png
#   inflating: input/610.png
#   inflating: input/604.png
#   inflating: input/162.png
#   inflating: input/002.png
#   inflating: input/016.png
#   inflating: input/228.png
#   inflating: input/566.png
#   inflating: input/200.png
#   inflating: input/214.png
#   inflating: input/572.png
#   inflating: input/599.png
#   inflating: input/215.png
#   inflating: input/573.png
#   inflating: input/567.png
#   inflating: input/201.png
#   inflating: input/229.png
#   inflating: input/017.png
#   inflating: input/003.png
#   inflating: input/605.png
#   inflating: input/163.png
#   inflating: input/177.png
#   inflating: input/611.png
#   inflating: input/639.png
#   inflating: input/407.png
# ...
